# %% [markdown]
# # Stanford Question Answering Dataset (SQuAD)

# %%
# Загрузка датасета из файла JSON
with open('data/aqa_v1.0/1_dbidaf/train.json', 'r', encoding='utf-8') as file:
    data_t = json.load(file)

# Преобразование данных в плоский формат
records = []
for item in data_t['data']:
    # title = item['title']
    for paragraph in item['paragraphs']:
        # context = paragraph['context']
        for qa in paragraph['qas']:
            question = qa['question']
            for answer in qa['answers']:
                record = {
                    # 'title': title,
                    # 'context': context,
                    'question': question,
                    # 'answer_start': answer['answer_start'],
                    'answer_text': answer['text']
                }
                records.append(record)

# Создание DataFrame
df = pd.DataFrame(records)

# Вывод первых 10 строк для проверки
df.head(10)

# %% [markdown]
# # Cagle wiki questions dataset

# %%
# with open('data/qas/S08_question_answer_pairs.txt', 'r', encoding='utf-8') as file:
#     data_t = json.load(file)
file_path = 'data/qas/S08_question_answer_pairs.txt'
# Создание DataFrame
# Создание DataFrame
df = pd.read_csv(file_path, delimiter='\t')

# Выбор только необходимых столбцов
df_filtered = df[['Question', 'Answer']]

df_filtered = df_filtered.drop_duplicates(subset=['Question'])

# Вывод первых 10 строк для проверки
df_filtered.head(15)

# %%
df_filtered['Answer'] = df_filtered['Answer'].str.lower().str.strip('.')

# Подсчет количества строк с ответом "yes" и "no"
answer_counts = df_filtered['Answer'].value_counts()

# Вывод результатов
yes_count = answer_counts.get('yes', 0)
no_count = answer_counts.get('no', 0)
total_rows = df_filtered.shape[0]

# Вывод общего количества строк

total_rows, yes_count, no_count

# %%
df_filtered['AnswerLength'] = df_filtered['Answer'].str.len()

# Сортировка датафрейма по длине ответов и выбор 5 самых длинных
longest_answers = df_filtered.sort_values(by='AnswerLength', ascending=False).head(15)

# Вывод 5 самых длинных ответов
longest_answers[['Question', 'Answer']]

# %%
# Функция для загрузки и предварительной обработки данных из файла
def load_and_preprocess(file_path):
    df = pd.read_csv(file_path, delimiter='\t', encoding='ISO-8859-1')
    df_filtered = df[['Question', 'Answer']]
    return df_filtered.drop_duplicates(subset=['Question'])

# Пути к файлам
file_paths = ['data/qas/S08_question_answer_pairs.txt', 'data/qas/S09_question_answer_pairs.txt', 'data/qas/S10_question_answer_pairs.txt']

# Загрузка и объединение данных из всех файлов
combined_df = pd.concat([load_and_preprocess(file_path) for file_path in file_paths], ignore_index=True)

# Удаление дубликатов после объединения
combined_df = combined_df.drop_duplicates(subset=['Question'])

# Вывод первых 10 строк для проверки
combined_df.head(10)

# %%
# Подсчет количества строк с ответом "yes" и "no"
answer_counts = df_filtered['Answer'].value_counts()

# Вывод результатов
yes_count = answer_counts.get('yes', 0)
no_count = answer_counts.get('no', 0)
total_rows = df_filtered.shape[0]

# Вывод общего количества строк

total_rows, yes_count, no_count

# %%
import pandas as pd
from openai import OpenAI

# %%
# Функция для загрузки и предварительной обработки данных из файла
def load_and_preprocess(file_path):
    df = pd.read_csv(file_path, delimiter='\t', encoding='ISO-8859-1')
    df_filtered = df[['Question', 'Answer']]
    return df_filtered.drop_duplicates(subset=['Question'])

# %%
file_paths = ['data/qas/S08_quest000ion_answer_pairs.txt', 'data/qas/S09_question_answer_pairs.txt', 'data/qas/S10_question_answer_pairs.txt']

combined_df = pd.concat([load_and_preprocess(file_path) for file_path in file_paths], ignore_index=True)
combined_df = combined_df.drop_duplicates(subset=['Question'])
combined_df = combined_df.loc[combined_df['Answer'].str.lower().isin(['yes', 'no'])]

combined_df.head(10)
# Out:
#                                              Question Answer
# 0   Was Abraham Lincoln the sixteenth President of...    yes
# 1   Did Lincoln sign the National Banking Act of 1...    yes
# 2                    Did his mother die of pneumonia?     no
# 8   Did Lincoln beat John C. Breckinridge in the 1...    yes
# 9   Was Abraham Lincoln the first President of the...     No
# 10    Did Lincoln start his political career in 1832?    Yes
# 11  Did Lincoln ever represent Alton & Sangamon Ra...    Yes
# 15              Did Lincoln win the election of 1860?    Yes
# 51     Is it true that he became a professor in 1820?    yes
# 52  Was Lorenzo Romano Amedeo Carlo Avogadro an It...    yes

# %%
print(f"Количество вопросов: {len(combined_df)}")
# Out:
# Количество вопросов: 787

# %%
# Настройка клиента OpenAI для работы с локальным сервером
client = OpenAI(base_url="http://localhost:1234/v1", api_key="lm-studio")
output_path = 'data/qas/combined_dataset_with_responses_t1.json'

# %%
# Функция для получения ответа от модели
def get_model_response(question):
    try:
        completion = client.chat.completions.create(
            model="lmstudio-community/Meta-Llama-3-8B-Instruct-GGUF",
            
            messages=[
                {"role": "system", "content": "You are a helpful assistant. You have to provide complete answer without explicitly saying 'yes' or 'no'."},
                {"role": "user", "content": question}
            ],
            temperature=1,
        )
        response = completion.choices[0].message.content
        return response
    except Exception as e:
        print(f"Error with question: {question}\n{e}\n")
        return "Error"

# %%
try:
    existing_df = pd.read_json(output_path, orient='records', lines=True)
    combined_df = combined_df.merge(existing_df, on=['Question', 'Answer'], how='left')
except FileNotFoundError:
    combined_df['ModelResponse'] = None

for index, row in combined_df.iterrows():
    if pd.isna(row['ModelResponse']):
        combined_df.at[index, 'ModelResponse'] = get_model_response(row['Question'])
        combined_df.to_json(output_path, orient='records', lines=True)
        print(f"Processed {index + 1}/{len(combined_df)}")

print(f"Итоговый датасет сохранен в {output_path}")
# Out:
# Processed 384/787
# Processed 385/787
# Processed 386/787
# Processed 387/787
# Processed 388/787
# Processed 389/787
# Processed 390/787
# Processed 391/787
# Processed 392/787
# Processed 393/787
# Processed 394/787
# Processed 395/787
# Processed 396/787
# Processed 397/787
# Processed 398/787
# Processed 399/787
# Processed 400/787
# Processed 401/787
# Processed 402/787
# Processed 403/787
# Processed 404/787
# Processed 405/787
# Processed 406/787
# Processed 407/787
# Processed 408/787
# Processed 409/787
# Processed 410/787
# Processed 411/787
# Processed 412/787
# Processed 413/787
# Processed 414/787
# Processed 415/787
# Processed 416/787
# Processed 417/787
# Processed 418/787
# Processed 419/787
# Processed 420/787
# Processed 421/787
# Processed 422/787
# Processed 423/787
# Processed 424/787
# Processed 425/787
# Processed 426/787
# Processed 427/787
# Processed 428/787
# Processed 429/787
# Processed 430/787
# Processed 431/787
# Processed 432/787
# Processed 433/787
# Processed 434/787
# Processed 435/787
# Processed 436/787
# Processed 437/787
# Processed 438/787
# Processed 439/787
# Processed 440/787
# Processed 441/787
# Processed 442/787
# Processed 443/787
# Processed 444/787
# Processed 445/787
# Processed 446/787
# Processed 447/787
# Processed 448/787
# Processed 449/787
# Processed 450/787
# Processed 451/787
# Processed 452/787
# Processed 453/787
# Processed 454/787
# Processed 455/787
# Processed 456/787
# Processed 457/787
# Processed 458/787
# Processed 459/787
# Processed 460/787
# Processed 461/787
# Processed 462/787
# Processed 463/787
# Processed 464/787
# Processed 465/787
# Processed 466/787
# Processed 467/787
# Processed 468/787
# Processed 469/787
# Processed 470/787
# Processed 471/787
# Processed 472/787
# Processed 473/787
# Processed 474/787
# Processed 475/787
# Processed 476/787
# Processed 477/787
# Processed 478/787
# Processed 479/787
# Processed 480/787
# Processed 481/787
# Processed 482/787
# Processed 483/787
# Processed 484/787
# Processed 485/787
# Processed 486/787
# Processed 487/787
# Processed 488/787
# Processed 489/787
# Processed 490/787
# Processed 491/787
# Processed 492/787
# Processed 493/787
# Processed 494/787
# Processed 495/787
# Processed 496/787
# Processed 497/787
# Processed 498/787
# Processed 499/787
# Processed 500/787
# Processed 501/787
# Processed 502/787
# Processed 503/787
# Processed 504/787
# Processed 505/787
# Processed 506/787
# Processed 507/787
# Processed 508/787
# Processed 509/787
# Processed 510/787
# Processed 511/787
# Processed 512/787
# Processed 513/787
# Processed 514/787
# Processed 515/787
# Processed 516/787
# Processed 517/787
# Processed 518/787
# Processed 519/787
# Processed 520/787
# Processed 521/787
# Processed 522/787
# Processed 523/787
# Processed 524/787
# Processed 525/787
# Processed 526/787
# Processed 527/787
# Processed 528/787
# Processed 529/787
# Processed 530/787
# Processed 531/787
# Processed 532/787
# Processed 533/787
# Processed 534/787
# Processed 535/787
# Processed 536/787
# Processed 537/787
# Processed 538/787
# Processed 539/787
# Processed 540/787
# Processed 541/787
# Processed 542/787
# Processed 543/787
# Processed 544/787
# Processed 545/787
# Processed 546/787
# Processed 547/787
# Processed 548/787
# Processed 549/787
# Processed 550/787
# Processed 551/787
# Processed 552/787
# Processed 553/787
# Processed 554/787
# Processed 555/787
# Processed 556/787
# Processed 557/787
# Processed 558/787
# Processed 559/787
# Processed 560/787
# Processed 561/787
# Processed 562/787
# Processed 563/787
# Processed 564/787
# Processed 565/787
# Processed 566/787
# Processed 567/787
# Processed 568/787
# Processed 569/787
# Processed 570/787
# Processed 571/787
# Processed 572/787
# Processed 573/787
# Processed 574/787
# Processed 575/787
# Processed 576/787
# Processed 577/787
# Processed 578/787
# Processed 579/787
# Processed 580/787
# Processed 581/787
# Processed 582/787
# Processed 583/787
# Processed 584/787
# Processed 585/787
# Processed 586/787
# Processed 587/787
# Processed 588/787
# Processed 589/787
# Processed 590/787
# Processed 591/787
# Processed 592/787
# Processed 593/787
# Processed 594/787
# Processed 595/787
# Processed 596/787
# Processed 597/787
# Processed 598/787
# Processed 599/787
# Processed 600/787
# Processed 601/787
# Processed 602/787
# Processed 603/787
# Processed 604/787
# Processed 605/787
# Processed 606/787
# Processed 607/787
# Processed 608/787
# Processed 609/787
# Processed 610/787
# Processed 611/787
# Processed 612/787
# Processed 613/787
# Processed 614/787
# Processed 615/787
# Processed 616/787
# Processed 617/787
# Processed 618/787
# Processed 619/787
# Processed 620/787
# Processed 621/787
# Processed 622/787
# Processed 623/787
# Processed 624/787
# Processed 625/787
# Processed 626/787
# Processed 627/787
# Processed 628/787
# Processed 629/787
# Processed 630/787
# Processed 631/787
# Processed 632/787
# Processed 633/787
# Processed 634/787
# Processed 635/787
# Processed 636/787
# Processed 637/787
# Processed 638/787
# Processed 639/787
# Processed 640/787
# Processed 641/787
# Processed 642/787
# Processed 643/787
# Processed 644/787
# Processed 645/787
# Processed 646/787
# Processed 647/787
# Processed 648/787
# Processed 649/787
# Processed 650/787
# Processed 651/787
# Processed 652/787
# Processed 653/787
# Processed 654/787
# Processed 655/787
# Processed 656/787
# Processed 657/787
# Processed 658/787
# Processed 659/787
# Processed 660/787
# Processed 661/787
# Processed 662/787
# Processed 663/787
# Processed 664/787
# Processed 665/787
# Processed 666/787
# Processed 667/787
# Processed 668/787
# Processed 669/787
# Processed 670/787
# Processed 671/787
# Processed 672/787
# Processed 673/787
# Processed 674/787
# Processed 675/787
# Processed 676/787
# Processed 677/787
# Processed 678/787
# Processed 679/787
# Processed 680/787
# Processed 681/787
# Processed 682/787
# Processed 683/787
# Processed 684/787
# Processed 685/787
# Processed 686/787
# Processed 687/787
# Processed 688/787
# Processed 689/787
# Processed 690/787
# Processed 691/787
# Processed 692/787
# Processed 693/787
# Processed 694/787
# Processed 695/787
# Processed 696/787
# Processed 697/787
# Processed 698/787
# Processed 699/787
# Processed 700/787
# Processed 701/787
# Processed 702/787
# Processed 703/787
# Processed 704/787
# Processed 705/787
# Processed 706/787
# Processed 707/787
# Processed 708/787
# Processed 709/787
# Processed 710/787
# Processed 711/787
# Processed 712/787
# Processed 713/787
# Processed 714/787
# Processed 715/787
# Processed 716/787
# Processed 717/787
# Processed 718/787
# Processed 719/787
# Processed 720/787
# Processed 721/787
# Processed 722/787
# Processed 723/787
# Processed 724/787
# Processed 725/787
# Processed 726/787
# Processed 727/787
# Processed 728/787
# Processed 729/787
# Processed 730/787
# Processed 731/787
# Processed 732/787
# Processed 733/787
# Processed 734/787
# Processed 735/787
# Processed 736/787
# Processed 737/787
# Processed 738/787
# Processed 739/787
# Processed 740/787
# Processed 741/787
# Processed 742/787
# Processed 743/787
# Processed 744/787
# Processed 745/787
# Processed 746/787
# Processed 747/787
# Processed 748/787
# Processed 749/787
# Processed 750/787
# Processed 751/787
# Processed 752/787
# Processed 753/787
# Processed 754/787
# Processed 755/787
# Processed 756/787
# Processed 757/787
# Processed 758/787
# Processed 759/787
# Processed 760/787
# Processed 761/787
# Processed 762/787
# Processed 763/787
# Processed 764/787
# Processed 765/787
# Processed 766/787
# Processed 767/787
# Processed 768/787
# Processed 769/787
# Processed 770/787
# Processed 771/787
# Processed 772/787
# Processed 773/787
# Processed 774/787
# Processed 775/787
# Processed 776/787
# Processed 777/787
# Processed 778/787
# Processed 779/787
# Processed 780/787
# Processed 781/787
# Processed 782/787
# Processed 783/787
# Processed 784/787
# Processed 785/787
# Processed 786/787
# Processed 787/787
# Итоговый датасет сохранен в data/qas/combined_dataset_with_responses_t1.json

# %%
combined_df
# Out:
#                                               Question Answer  \
# 0    Was Abraham Lincoln the sixteenth President of...    yes
# 1    Did Lincoln sign the National Banking Act of 1...    yes
# 2                     Did his mother die of pneumonia?     no
# 3    Did Lincoln beat John C. Breckinridge in the 1...    yes
# 4    Was Abraham Lincoln the first President of the...     No
# ..                                                 ...    ...
# 782  Was it likely that the xylophone reached Europ...    yes
# 783  Does kelon increase or decrease tone quality o...     no
# 784     Do the different species of zebras interbreed?     no
# 785                       Do zebras sleep standing up?    yes
# 786  Have plains zebras been crossed with mountain ...    yes
#
#                                        ModelResponse_x  \
# 0    Yes, Abraham Lincoln was indeed the 16th Presi...
# 1    No, Abraham Lincoln did not sign the National ...
# 2    I apologize, but there is no information provi...
# 3    Actually, Abraham Lincoln did not face John C....
# 4    No, Abraham Lincoln was not the first Presiden...
# ..                                                 ...
# 782                                               None
# 783                                               None
# 784                                               None
# 785                                               None
# 786                                               None
#
#                                        ModelResponse_y  \
# 0    Yes, Abraham Lincoln was indeed the 16th Presi...
# 1    No, Abraham Lincoln did not sign the National ...
# 2    I apologize, but there is no information provi...
# 3    Actually, Abraham Lincoln did not face John C....
# 4    No, Abraham Lincoln was not the first Presiden...
# ..                                                 ...
# 782                                               None
# 783                                               None
# 784                                               None
# 785                                               None
# 786                                               None
#
#                                          ModelResponse
# 0    Yes, Abraham Lincoln was indeed the 16th Presi...
# 1    No, Abraham Lincoln did not sign the National ...
# 2    I apologize, but there is no information provi...
# 3    Actually, Abraham Lincoln did not face John C....
# 4    No, Abraham Lincoln was not the first Presiden...
# ..                                                 ...
# 782  The xylophone, an ancient instrument originati...
# 783  Kelon, which is a type of tuning material used...
# 784  The three main species of zebras, the plains z...
# 785  Zebras, being equines, do not typically sleep ...
# 786  While there is no evidence of intentional bree...
#
# [787 rows x 5 columns]

# %%
# Загрузка двух файлов с разными температурами
df1 = pd.read_json('data/qas/combined_dataset_with_responses_t1.json', orient='records', lines=True)
df2 = pd.read_json('data/qas/combined_dataset_with_responses.json', orient='records', lines=True)

# Проверка существующих столбцов и удаление лишних
columns_to_drop = ['ModelResponse_x', 'ModelResponse_y']
for col in columns_to_drop:
    if col in df1.columns:
        df1 = df1.drop(columns=[col])
    if col in df2.columns:
        df2 = df2.drop(columns=[col])

# Объединение датафреймов
combined_df = pd.concat([df1, df2], ignore_index=True)


# Сохранение объединенного датафрейма
combined_output_path = 'data/qas/combined_dataset.json'
combined_df.to_json(combined_output_path, orient='records', lines=True)
print(f"Объединенный датасет сохранен в {combined_output_path}")
# Out:
# Объединенный датасет сохранен в data/qas/combined_dataset.json

# %%
len(df1), len(df2), len(combined_df)
# Out:
# (787, 787, 1574)

# %%
combined_df
# Out:
#                                                Question Answer  \
# 0     Was Abraham Lincoln the sixteenth President of...    yes
# 1     Did Lincoln sign the National Banking Act of 1...    yes
# 2                      Did his mother die of pneumonia?     no
# 3     Did Lincoln beat John C. Breckinridge in the 1...    yes
# 4     Was Abraham Lincoln the first President of the...     No
# ...                                                 ...    ...
# 1569  Was it likely that the xylophone reached Europ...    yes
# 1570  Does kelon increase or decrease tone quality o...     no
# 1571     Do the different species of zebras interbreed?     no
# 1572                       Do zebras sleep standing up?    yes
# 1573  Have plains zebras been crossed with mountain ...    yes
#
#                                           ModelResponse
# 0     Yes, Abraham Lincoln was indeed the 16th Presi...
# 1     No, Abraham Lincoln did not sign the National ...
# 2     I apologize, but there is no information provi...
# 3     Actually, Abraham Lincoln did not face John C....
# 4     No, Abraham Lincoln was not the first Presiden...
# ...                                                 ...
# 1569  It's possible that the xylophone may have reac...
# 1570  Kelvon (not Kelon) is not a specific type of x...
# 1571  Yes, the three main species of zebras - plains...
# 1572  No, zebras do not sleep standing up. Like many...
# 1573  Yes, plains zebras (Equus quagga) and mountain...
#
# [1574 rows x 3 columns]

# %%
# Загрузка промежуточных данных, если файл существует
output_path = 'data/qas/combined_dataset_with_responses_and_classification.json'
try:
    existing_df = pd.read_json(output_path, orient='records', lines=True)
    # Приведение столбца ModelResponse к строковому типу данных
    existing_df['ModelResponse'] = existing_df['ModelResponse'].astype(str)
    combined_df = combined_df.merge(existing_df, on=['Question', 'Answer', 'ModelResponse'], how='left')
    combined_df['Classification'] = combined_df['Classification'].fillna(existing_df['Classification'])
except FileNotFoundError:
    combined_df['Classification'] = None

# %%
combined_df
# Out:
#                                                Question Answer  \
# 0     Was Abraham Lincoln the sixteenth President of...    yes
# 1     Did Lincoln sign the National Banking Act of 1...    yes
# 2                      Did his mother die of pneumonia?     no
# 3     Did Lincoln beat John C. Breckinridge in the 1...    yes
# 4     Was Abraham Lincoln the first President of the...     No
# ...                                                 ...    ...
# 1579  Was it likely that the xylophone reached Europ...    yes
# 1580  Does kelon increase or decrease tone quality o...     no
# 1581     Do the different species of zebras interbreed?     no
# 1582                       Do zebras sleep standing up?    yes
# 1583  Have plains zebras been crossed with mountain ...    yes
#
#                                           ModelResponse Classification
# 0     Yes, Abraham Lincoln was indeed the 16th Presi...           None
# 1     No, Abraham Lincoln did not sign the National ...           None
# 2     I apologize, but there is no information provi...           None
# 3     Actually, Abraham Lincoln did not face John C....           None
# 4     No, Abraham Lincoln was not the first Presiden...           None
# ...                                                 ...            ...
# 1579  It's possible that the xylophone may have reac...           None
# 1580  Kelvon (not Kelon) is not a specific type of x...           None
# 1581  Yes, the three main species of zebras - plains...           None
# 1582  No, zebras do not sleep standing up. Like many...           None
# 1583  Yes, plains zebras (Equus quagga) and mountain...           None
#
# [1584 rows x 4 columns]

# %%
# Функция для классификации ответов
def classify_response(question, model_response):
    prompt = f"Question: {question}\nAnswer: {model_response}\nClassify the answer as 'yes', 'no', or 'neither'."
    try:
        completion = client.chat.completions.create(
            model="lmstudio-community/Meta-Llama-3-8B-Instruct-GGUF",
            messages=[
                {"role": "system", "content": "You are a helpful assistant. You have to provide answer 'yes', 'no' or 'neither'."},
                {"role": "user", "content": prompt}
            ],
            temperature=0.1,
        )
        response = completion.choices[0].message.content.strip().lower()
        if 'yes' in response:
            return 'yes'
        elif 'no' in response:
            return 'no'
        else:
            return 'neither'
    except Exception as e:
        print(f"Error with question: {question}\n{e}\n")
        return "neither"

# Применение функции к каждому вопросу и ответу в датафрейме и сохранение результатов
for index, row in combined_df.iterrows():
    if pd.isna(row['Classification']):
        combined_df.at[index, 'Classification'] = classify_response(row['Question'], row['ModelResponse'])
        combined_df.to_json(output_path, orient='records', lines=True)
        print(f"Processed {index + 1}/{len(combined_df)}")

# Сохранение итогового датафрейма в JSON
classified_output_path = 'data/qas/combined_dataset_with_classification.json'
combined_df.to_json(classified_output_path, orient='records', lines=True)

print(f"Итоговый датасет с классификацией сохранен в {classified_output_path}")
# Out:
# Processed 1/1584
# Processed 2/1584
# Processed 3/1584
# Processed 4/1584
# Processed 5/1584
# Processed 6/1584
# Processed 7/1584
# Processed 8/1584
# Processed 9/1584
# Processed 10/1584
# Processed 11/1584
# Processed 12/1584
# Processed 13/1584
# Processed 14/1584
# Processed 15/1584
# Processed 16/1584
# Processed 17/1584
# Processed 18/1584
# Processed 19/1584
# Processed 20/1584
# Processed 21/1584
# Processed 22/1584
# Processed 23/1584
# Processed 24/1584
# Processed 25/1584
# Processed 26/1584
# Processed 27/1584
# Processed 28/1584
# Processed 29/1584
# Processed 30/1584
# Processed 31/1584
# Processed 32/1584
# Processed 33/1584
# Processed 34/1584
# Processed 35/1584
# Processed 36/1584
# Processed 37/1584
# Processed 38/1584
# Processed 39/1584
# Processed 40/1584
# Processed 41/1584
# Processed 42/1584
# Processed 43/1584
# Processed 44/1584
# Processed 45/1584
# Processed 46/1584
# Processed 47/1584
# Processed 48/1584
# Processed 49/1584
# Processed 50/1584
# Processed 51/1584
# Processed 52/1584
# Processed 53/1584
# Processed 54/1584
# Processed 55/1584
# Processed 56/1584
# Processed 57/1584
# Processed 58/1584
# Processed 59/1584
# Processed 60/1584
# Processed 61/1584
# Processed 62/1584
# Processed 63/1584
# Processed 64/1584
# Processed 65/1584
# Processed 66/1584
# Processed 67/1584
# Processed 68/1584
# Processed 69/1584
# Processed 70/1584
# Processed 71/1584
# Processed 72/1584
# Processed 73/1584
# Processed 74/1584
# Processed 75/1584
# Processed 76/1584
# Processed 77/1584
# Processed 78/1584
# Processed 79/1584
# Processed 80/1584
# Processed 81/1584
# Processed 82/1584
# Processed 83/1584
# Processed 84/1584
# Processed 85/1584
# Processed 86/1584
# Processed 87/1584
# Processed 88/1584
# Processed 89/1584
# Processed 90/1584
# Processed 91/1584
# Processed 92/1584
# Processed 93/1584
# Processed 94/1584
# Processed 95/1584
# Processed 96/1584
# Processed 97/1584
# Processed 98/1584
# Processed 99/1584
# Processed 100/1584
# Processed 101/1584
# Processed 102/1584
# Processed 103/1584
# Processed 104/1584
# Processed 105/1584
# Processed 106/1584
# Processed 107/1584
# Processed 108/1584
# Processed 109/1584
# Processed 110/1584
# Processed 111/1584
# Processed 112/1584
# Processed 113/1584
# Processed 114/1584
# Processed 115/1584
# Processed 116/1584
# Processed 117/1584
# Processed 118/1584
# Processed 119/1584
# Processed 120/1584
# Processed 121/1584
# Processed 122/1584
# Processed 123/1584
# Processed 124/1584
# Processed 125/1584
# Processed 126/1584
# Processed 127/1584
# Processed 128/1584
# Processed 129/1584
# Processed 130/1584
# Processed 131/1584
# Processed 132/1584
# Processed 133/1584
# Processed 134/1584
# Processed 135/1584
# Processed 136/1584
# Processed 137/1584
# Processed 138/1584
# Processed 139/1584
# Processed 140/1584
# Processed 141/1584
# Processed 142/1584
# Processed 143/1584
# Processed 144/1584
# Processed 145/1584
# Processed 146/1584
# Processed 147/1584
# Processed 148/1584
# Processed 149/1584
# Processed 150/1584
# Processed 151/1584
# Processed 152/1584
# Processed 153/1584
# Processed 154/1584
# Processed 155/1584
# Processed 156/1584
# Processed 157/1584
# Processed 158/1584
# Processed 159/1584
# Processed 160/1584
# Processed 161/1584
# Processed 162/1584
# Processed 163/1584
# Processed 164/1584
# Processed 165/1584
# Processed 166/1584
# Processed 167/1584
# Processed 168/1584
# Processed 169/1584
# Processed 170/1584
# Processed 171/1584
# Processed 172/1584
# Processed 173/1584
# Processed 174/1584
# Processed 175/1584
# Processed 176/1584
# Processed 177/1584
# Processed 178/1584
# Processed 179/1584
# Processed 180/1584
# Processed 181/1584
# Processed 182/1584
# Processed 183/1584
# Processed 184/1584
# Processed 185/1584
# Processed 186/1584
# Processed 187/1584
# Processed 188/1584
# Processed 189/1584
# Processed 190/1584
# Processed 191/1584
# Processed 192/1584
# Processed 193/1584
# Processed 194/1584
# Processed 195/1584
# Processed 196/1584
# Processed 197/1584
# Processed 198/1584
# Processed 199/1584
# Processed 200/1584
# Processed 201/1584
# Processed 202/1584
# Processed 203/1584
# Processed 204/1584
# Processed 205/1584
# Processed 206/1584
# Processed 207/1584
# Processed 208/1584
# Processed 209/1584
# Processed 210/1584
# Processed 211/1584
# Processed 212/1584
# Processed 213/1584
# Processed 214/1584
# Processed 215/1584
# Processed 216/1584
# Processed 217/1584
# Processed 218/1584
# Processed 219/1584
# Processed 220/1584
# Processed 221/1584
# Processed 222/1584
# Processed 223/1584
# Processed 224/1584
# Processed 225/1584
# Processed 226/1584
# Processed 227/1584
# Processed 228/1584
# Processed 229/1584
# Processed 230/1584
# Processed 231/1584
# Processed 232/1584
# Processed 233/1584
# Processed 234/1584
# Processed 235/1584
# Processed 236/1584
# Processed 237/1584
# Processed 238/1584
# Processed 239/1584
# Processed 240/1584
# Processed 241/1584
# Processed 242/1584
# Processed 243/1584
# Processed 244/1584
# Processed 245/1584
# Processed 246/1584
# Processed 247/1584
# Processed 248/1584
# Processed 249/1584
# Processed 250/1584
# Processed 251/1584
# Processed 252/1584
# Processed 253/1584
# Processed 254/1584
# Processed 255/1584
# Processed 256/1584
# Processed 257/1584
# Processed 258/1584
# Processed 259/1584
# Processed 260/1584
# Processed 261/1584
# Processed 262/1584
# Processed 263/1584
# Processed 264/1584
# Processed 265/1584
# Processed 266/1584
# Processed 267/1584
# Processed 268/1584
# Processed 269/1584
# Processed 270/1584
# Processed 271/1584
# Processed 272/1584
# Processed 273/1584
# Processed 274/1584
# Processed 275/1584
# Processed 276/1584
# Processed 277/1584
# Processed 278/1584
# Processed 279/1584
# Processed 280/1584
# Processed 281/1584
# Processed 282/1584
# Processed 283/1584
# Processed 284/1584
# Processed 285/1584
# Processed 286/1584
# Processed 287/1584
# Processed 288/1584
# Processed 289/1584
# Processed 290/1584
# Processed 291/1584
# Processed 292/1584
# Processed 293/1584
# Processed 294/1584
# Processed 295/1584
# Processed 296/1584
# Processed 297/1584
# Processed 298/1584
# Processed 299/1584
# Processed 300/1584
# Processed 301/1584
# Processed 302/1584
# Processed 303/1584
# Processed 304/1584
# Processed 305/1584
# Processed 306/1584
# Processed 307/1584
# Processed 308/1584
# Processed 309/1584
# Processed 310/1584
# Processed 311/1584
# Processed 312/1584
# Processed 313/1584
# Processed 314/1584
# Processed 315/1584
# Processed 316/1584
# Processed 317/1584
# Processed 318/1584
# Processed 319/1584
# Processed 320/1584
# Processed 321/1584
# Processed 322/1584
# Processed 323/1584
# Processed 324/1584
# Processed 325/1584
# Processed 326/1584
# Processed 327/1584
# Processed 328/1584
# Processed 329/1584
# Processed 330/1584
# Processed 331/1584
# Processed 332/1584
# Processed 333/1584
# Processed 334/1584
# Processed 335/1584
# Processed 336/1584
# Processed 337/1584
# Processed 338/1584
# Processed 339/1584
# Processed 340/1584
# Processed 341/1584
# Processed 342/1584
# Processed 343/1584
# Processed 344/1584
# Processed 345/1584
# Processed 346/1584
# Processed 347/1584
# Processed 348/1584
# Processed 349/1584
# Processed 350/1584
# Processed 351/1584
# Processed 352/1584
# Processed 353/1584
# Processed 354/1584
# Processed 355/1584
# Processed 356/1584
# Processed 357/1584
# Processed 358/1584
# Processed 359/1584
# Processed 360/1584
# Processed 361/1584
# Processed 362/1584
# Processed 363/1584
# Processed 364/1584
# Processed 365/1584
# Processed 366/1584
# Processed 367/1584
# Processed 368/1584
# Processed 369/1584
# Processed 370/1584
# Processed 371/1584
# Processed 372/1584
# Processed 373/1584
# Processed 374/1584
# Processed 375/1584
# Processed 376/1584
# Processed 377/1584
# Processed 378/1584
# Processed 379/1584
# Processed 380/1584
# Processed 381/1584
# Processed 382/1584
# Processed 383/1584
# Processed 384/1584
# Processed 385/1584
# Processed 386/1584
# Processed 387/1584
# Processed 388/1584
# Processed 389/1584
# Processed 390/1584
# Processed 391/1584
# Processed 392/1584
# Processed 393/1584
# Processed 394/1584
# Processed 395/1584
# Processed 396/1584
# Processed 397/1584
# Processed 398/1584
# Processed 399/1584
# Processed 400/1584
# Processed 401/1584
# Processed 402/1584
# Processed 403/1584
# Processed 404/1584
# Processed 405/1584
# Processed 406/1584
# Processed 407/1584
# Processed 408/1584
# Processed 409/1584
# Processed 410/1584
# Processed 411/1584
# Processed 412/1584
# Processed 413/1584
# Processed 414/1584
# Processed 415/1584
# Processed 416/1584
# Processed 417/1584
# Processed 418/1584
# Processed 419/1584
# Processed 420/1584
# Processed 421/1584
# Processed 422/1584
# Processed 423/1584
# Processed 424/1584
# Processed 425/1584
# Processed 426/1584
# Processed 427/1584
# Processed 428/1584
# Processed 429/1584
# Processed 430/1584
# Processed 431/1584
# Processed 432/1584
# Processed 433/1584
# Processed 434/1584
# Processed 435/1584
# Processed 436/1584
# Processed 437/1584
# Processed 438/1584
# Processed 439/1584
# Processed 440/1584
# Processed 441/1584
# Processed 442/1584
# Processed 443/1584
# Processed 444/1584
# Processed 445/1584
# Processed 446/1584
# Processed 447/1584
# Processed 448/1584
# Processed 449/1584
# Processed 450/1584
# Processed 451/1584
# Processed 452/1584
# Processed 453/1584
# Processed 454/1584
# Processed 455/1584
# Processed 456/1584
# Processed 457/1584
# Processed 458/1584
# Processed 459/1584
# Processed 460/1584
# Processed 461/1584
# Processed 462/1584
# Processed 463/1584
# Processed 464/1584
# Processed 465/1584
# Processed 466/1584
# Processed 467/1584
# Processed 468/1584
# Processed 469/1584
# Processed 470/1584
# Processed 471/1584
# Processed 472/1584
# Processed 473/1584
# Processed 474/1584
# Processed 475/1584
# Processed 476/1584
# Processed 477/1584
# Processed 478/1584
# Processed 479/1584
# Processed 480/1584
# Processed 481/1584
# Processed 482/1584
# Processed 483/1584
# Processed 484/1584
# Processed 485/1584
# Processed 486/1584
# Processed 487/1584
# Processed 488/1584
# Processed 489/1584
# Processed 490/1584
# Processed 491/1584
# Processed 492/1584
# Processed 493/1584
# Processed 494/1584
# Processed 495/1584
# Processed 496/1584
# Processed 497/1584
# Processed 498/1584
# Processed 499/1584
# Processed 500/1584
# Processed 501/1584
# Processed 502/1584
# Processed 503/1584
# Processed 504/1584
# Processed 505/1584
# Processed 506/1584
# Processed 507/1584
# Processed 508/1584
# Processed 509/1584
# Processed 510/1584
# Processed 511/1584
# Processed 512/1584
# Processed 513/1584
# Processed 514/1584
# Processed 515/1584
# Processed 516/1584
# Processed 517/1584
# Processed 518/1584
# Processed 519/1584
# Processed 520/1584
# Processed 521/1584
# Processed 522/1584
# Processed 523/1584
# Processed 524/1584
# Processed 525/1584
# Processed 526/1584
# Processed 527/1584
# Processed 528/1584
# Processed 529/1584
# Processed 530/1584
# Processed 531/1584
# Processed 532/1584
# Processed 533/1584
# Processed 534/1584
# Processed 535/1584
# Processed 536/1584
# Processed 537/1584
# Processed 538/1584
# Processed 539/1584
# Processed 540/1584
# Processed 541/1584
# Processed 542/1584
# Processed 543/1584
# Processed 544/1584
# Processed 545/1584
# Processed 546/1584
# Processed 547/1584
# Processed 548/1584
# Processed 549/1584
# Processed 550/1584
# Processed 551/1584
# Processed 552/1584
# Processed 553/1584
# Processed 554/1584
# Processed 555/1584
# Processed 556/1584
# Processed 557/1584
# Processed 558/1584
# Processed 559/1584
# Processed 560/1584
# Processed 561/1584
# Processed 562/1584
# Processed 563/1584
# Processed 564/1584
# Processed 565/1584
# Processed 566/1584
# Processed 567/1584
# Processed 568/1584
# Processed 569/1584
# Processed 570/1584
# Processed 571/1584
# Processed 572/1584
# Processed 573/1584
# Processed 574/1584
# Processed 575/1584
# Processed 576/1584
# Processed 577/1584
# Processed 578/1584
# Processed 579/1584
# Processed 580/1584
# Processed 581/1584
# Processed 582/1584
# Processed 583/1584
# Processed 584/1584
# Processed 585/1584
# Processed 586/1584
# Processed 587/1584
# Processed 588/1584
# Processed 589/1584
# Processed 590/1584
# Processed 591/1584
# Processed 592/1584
# Processed 593/1584
# Processed 594/1584
# Processed 595/1584
# Processed 596/1584
# Processed 597/1584
# Processed 598/1584
# Processed 599/1584
# Processed 600/1584
# Processed 601/1584
# Processed 602/1584
# Processed 603/1584
# Processed 604/1584
# Processed 605/1584
# Processed 606/1584
# Processed 607/1584
# Processed 608/1584
# Processed 609/1584
# Processed 610/1584
# Processed 611/1584
# Processed 612/1584
# Processed 613/1584
# Processed 614/1584
# Processed 615/1584
# Processed 616/1584
# Processed 617/1584
# Processed 618/1584
# Processed 619/1584
# Processed 620/1584
# Processed 621/1584
# Processed 622/1584
# Processed 623/1584
# Processed 624/1584
# Processed 625/1584
# Processed 626/1584
# Processed 627/1584
# Processed 628/1584
# Processed 629/1584
# Processed 630/1584
# Processed 631/1584
# Processed 632/1584
# Processed 633/1584
# Processed 634/1584
# Processed 635/1584
# Processed 636/1584
# Processed 637/1584
# Processed 638/1584
# Processed 639/1584
# Processed 640/1584
# Processed 641/1584
# Processed 642/1584
# Processed 643/1584
# Processed 644/1584
# Processed 645/1584
# Processed 646/1584
# Processed 647/1584
# Processed 648/1584
# Processed 649/1584
# Processed 650/1584
# Processed 651/1584
# Processed 652/1584
# Processed 653/1584
# Processed 654/1584
# Processed 655/1584
# Processed 656/1584
# Processed 657/1584
# Processed 658/1584
# Processed 659/1584
# Processed 660/1584
# Processed 661/1584
# Processed 662/1584
# Processed 663/1584
# Processed 664/1584
# Processed 665/1584
# Processed 666/1584
# Processed 667/1584
# Processed 668/1584
# Processed 669/1584
# Processed 670/1584
# Processed 671/1584
# Processed 672/1584
# Processed 673/1584
# Processed 674/1584
# Processed 675/1584
# Processed 676/1584
# Processed 677/1584
# Processed 678/1584
# Processed 679/1584
# Processed 680/1584
# Processed 681/1584
# Processed 682/1584
# Processed 683/1584
# Processed 684/1584
# Processed 685/1584
# Processed 686/1584
# Processed 687/1584
# Processed 688/1584
# Processed 689/1584
# Processed 690/1584
# Processed 691/1584
# Processed 692/1584
# Processed 693/1584
# Processed 694/1584
# Processed 695/1584
# Processed 696/1584
# Processed 697/1584
# Processed 698/1584
# Processed 699/1584
# Processed 700/1584
# Processed 701/1584
# Processed 702/1584
# Processed 703/1584
# Processed 704/1584
# Processed 705/1584
# Processed 706/1584
# Processed 707/1584
# Processed 708/1584
# Processed 709/1584
# Processed 710/1584
# Processed 711/1584
# Processed 712/1584
# Processed 713/1584
# Processed 714/1584
# Processed 715/1584
# Processed 716/1584
# Processed 717/1584
# Processed 718/1584
# Processed 719/1584
# Processed 720/1584
# Processed 721/1584
# Processed 722/1584
# Processed 723/1584
# Processed 724/1584
# Processed 725/1584
# Processed 726/1584
# Processed 727/1584
# Processed 728/1584
# Processed 729/1584
# Processed 730/1584
# Processed 731/1584
# Processed 732/1584
# Processed 733/1584
# Processed 734/1584
# Processed 735/1584
# Processed 736/1584
# Processed 737/1584
# Processed 738/1584
# Processed 739/1584
# Processed 740/1584
# Processed 741/1584
# Processed 742/1584
# Processed 743/1584
# Processed 744/1584
# Processed 745/1584
# Processed 746/1584
# Processed 747/1584
# Processed 748/1584
# Processed 749/1584
# Processed 750/1584
# Processed 751/1584
# Processed 752/1584
# Processed 753/1584
# Processed 754/1584
# Processed 755/1584
# Processed 756/1584
# Processed 757/1584
# Processed 758/1584
# Processed 759/1584
# Processed 760/1584
# Processed 761/1584
# Processed 762/1584
# Processed 763/1584
# Processed 764/1584
# Processed 765/1584
# Processed 766/1584
# Processed 767/1584
# Processed 768/1584
# Processed 769/1584
# Processed 770/1584
# Processed 771/1584
# Processed 772/1584
# Processed 773/1584
# Processed 774/1584
# Processed 775/1584
# Processed 776/1584
# Processed 777/1584
# Processed 778/1584
# Processed 779/1584
# Processed 780/1584
# Processed 781/1584
# Processed 782/1584
# Processed 783/1584
# Processed 784/1584
# Processed 785/1584
# Processed 786/1584
# Processed 787/1584
# Processed 788/1584
# Processed 789/1584
# Processed 790/1584
# Processed 791/1584
# Processed 792/1584
# Processed 793/1584
# Processed 794/1584
# Processed 795/1584
# Processed 796/1584
# Processed 797/1584
# Processed 798/1584
# Processed 799/1584
# Processed 800/1584
# Processed 801/1584
# Processed 802/1584
# Processed 803/1584
# Processed 804/1584
# Processed 805/1584
# Processed 806/1584
# Processed 807/1584
# Processed 808/1584
# Processed 809/1584
# Processed 810/1584
# Processed 811/1584
# Processed 812/1584
# Processed 813/1584
# Processed 814/1584
# Processed 815/1584
# Processed 816/1584
# Processed 817/1584
# Processed 818/1584
# Processed 819/1584
# Processed 820/1584
# Processed 821/1584
# Processed 822/1584
# Processed 823/1584
# Processed 824/1584
# Processed 825/1584
# Processed 826/1584
# Processed 827/1584
# Processed 828/1584
# Processed 829/1584
# Processed 830/1584
# Processed 831/1584
# Processed 832/1584
# Processed 833/1584
# Processed 834/1584
# Processed 835/1584
# Processed 836/1584
# Processed 837/1584
# Processed 838/1584
# Processed 839/1584
# Processed 840/1584
# Processed 841/1584
# Processed 842/1584
# Processed 843/1584
# Processed 844/1584
# Processed 845/1584
# Processed 846/1584
# Processed 847/1584
# Processed 848/1584
# Processed 849/1584
# Processed 850/1584
# Processed 851/1584
# Processed 852/1584
# Processed 853/1584
# Processed 854/1584
# Processed 855/1584
# Processed 856/1584
# Processed 857/1584
# Processed 858/1584
# Processed 859/1584
# Processed 860/1584
# Processed 861/1584
# Processed 862/1584
# Processed 863/1584
# Processed 864/1584
# Processed 865/1584
# Processed 866/1584
# Processed 867/1584
# Processed 868/1584
# Processed 869/1584
# Processed 870/1584
# Processed 871/1584
# Processed 872/1584
# Processed 873/1584
# Processed 874/1584
# Processed 875/1584
# Processed 876/1584
# Processed 877/1584
# Processed 878/1584
# Processed 879/1584
# Processed 880/1584
# Processed 881/1584
# Processed 882/1584
# Processed 883/1584
# Processed 884/1584
# Processed 885/1584
# Processed 886/1584
# Processed 887/1584
# Processed 888/1584
# Processed 889/1584
# Processed 890/1584
# Processed 891/1584
# Processed 892/1584
# Processed 893/1584
# Processed 894/1584
# Processed 895/1584
# Processed 896/1584
# Processed 897/1584
# Processed 898/1584
# Processed 899/1584
# Processed 900/1584
# Processed 901/1584
# Processed 902/1584
# Processed 903/1584
# Processed 904/1584
# Processed 905/1584
# Processed 906/1584
# Processed 907/1584
# Processed 908/1584
# Processed 909/1584
# Processed 910/1584
# Processed 911/1584
# Processed 912/1584
# Processed 913/1584
# Processed 914/1584
# Processed 915/1584
# Processed 916/1584
# Processed 917/1584
# Processed 918/1584
# Processed 919/1584
# Processed 920/1584
# Processed 921/1584
# Processed 922/1584
# Processed 923/1584
# Processed 924/1584
# Processed 925/1584
# Processed 926/1584
# Processed 927/1584
# Processed 928/1584
# Processed 929/1584
# Processed 930/1584
# Processed 931/1584
# Processed 932/1584
# Processed 933/1584
# Processed 934/1584
# Processed 935/1584
# Processed 936/1584
# Processed 937/1584
# Processed 938/1584
# Processed 939/1584
# Processed 940/1584
# Processed 941/1584
# Processed 942/1584
# Processed 943/1584
# Processed 944/1584
# Processed 945/1584
# Processed 946/1584
# Processed 947/1584
# Processed 948/1584
# Processed 949/1584
# Processed 950/1584
# Processed 951/1584
# Processed 952/1584
# Processed 953/1584
# Processed 954/1584
# Processed 955/1584
# Processed 956/1584
# Processed 957/1584
# Processed 958/1584
# Processed 959/1584
# Processed 960/1584
# Processed 961/1584
# Processed 962/1584
# Processed 963/1584
# Processed 964/1584
# Processed 965/1584
# Processed 966/1584
# Processed 967/1584
# Processed 968/1584
# Processed 969/1584
# Processed 970/1584
# Processed 971/1584
# Processed 972/1584
# Processed 973/1584
# Processed 974/1584
# Processed 975/1584
# Processed 976/1584
# Processed 977/1584
# Processed 978/1584
# Processed 979/1584
# Processed 980/1584
# Processed 981/1584
# Processed 982/1584
# Processed 983/1584
# Processed 984/1584
# Processed 985/1584
# Processed 986/1584
# Processed 987/1584
# Processed 988/1584
# Processed 989/1584
# Processed 990/1584
# Processed 991/1584
# Processed 992/1584
# Processed 993/1584
# Processed 994/1584
# Processed 995/1584
# Processed 996/1584
# Processed 997/1584
# Processed 998/1584
# Processed 999/1584
# Processed 1000/1584
# Processed 1001/1584
# Processed 1002/1584
# Processed 1003/1584
# Processed 1004/1584
# Processed 1005/1584
# Processed 1006/1584
# Processed 1007/1584
# Processed 1008/1584
# Processed 1009/1584
# Processed 1010/1584
# Processed 1011/1584
# Processed 1012/1584
# Processed 1013/1584
# Processed 1014/1584
# Processed 1015/1584
# Processed 1016/1584
# Processed 1017/1584
# Processed 1018/1584
# Processed 1019/1584
# Processed 1020/1584
# Processed 1021/1584
# Processed 1022/1584
# Processed 1023/1584
# Processed 1024/1584
# Processed 1025/1584
# Processed 1026/1584
# Processed 1027/1584
# Processed 1028/1584
# Processed 1029/1584
# Processed 1030/1584
# Processed 1031/1584
# Processed 1032/1584
# Processed 1033/1584
# Processed 1034/1584
# Processed 1035/1584
# Processed 1036/1584
# Processed 1037/1584
# Processed 1038/1584
# Processed 1039/1584
# Processed 1040/1584
# Processed 1041/1584
# Processed 1042/1584
# Processed 1043/1584
# Processed 1044/1584
# Processed 1045/1584
# Processed 1046/1584
# Processed 1047/1584
# Processed 1048/1584
# Processed 1049/1584
# Processed 1050/1584
# Processed 1051/1584
# Processed 1052/1584
# Processed 1053/1584
# Processed 1054/1584
# Processed 1055/1584
# Processed 1056/1584
# Processed 1057/1584
# Processed 1058/1584
# Processed 1059/1584
# Processed 1060/1584
# Processed 1061/1584
# Processed 1062/1584
# Processed 1063/1584
# Processed 1064/1584
# Processed 1065/1584
# Processed 1066/1584
# Processed 1067/1584
# Processed 1068/1584
# Processed 1069/1584
# Processed 1070/1584
# Processed 1071/1584
# Processed 1072/1584
# Processed 1073/1584
# Processed 1074/1584
# Processed 1075/1584
# Processed 1076/1584
# Processed 1077/1584
# Processed 1078/1584
# Processed 1079/1584
# Processed 1080/1584
# Processed 1081/1584
# Processed 1082/1584
# Processed 1083/1584
# Processed 1084/1584
# Processed 1085/1584
# Processed 1086/1584
# Processed 1087/1584
# Processed 1088/1584
# Processed 1089/1584
# Processed 1090/1584
# Processed 1091/1584
# Processed 1092/1584
# Processed 1093/1584
# Processed 1094/1584
# Processed 1095/1584
# Processed 1096/1584
# Processed 1097/1584
# Processed 1098/1584
# Processed 1099/1584
# Processed 1100/1584
# Processed 1101/1584
# Processed 1102/1584
# Processed 1103/1584
# Processed 1104/1584
# Processed 1105/1584
# Processed 1106/1584
# Processed 1107/1584
# Processed 1108/1584
# Processed 1109/1584
# Processed 1110/1584
# Processed 1111/1584
# Processed 1112/1584
# Processed 1113/1584
# Processed 1114/1584
# Processed 1115/1584
# Processed 1116/1584
# Processed 1117/1584
# Processed 1118/1584
# Processed 1119/1584
# Processed 1120/1584
# Processed 1121/1584
# Processed 1122/1584
# Processed 1123/1584
# Processed 1124/1584
# Processed 1125/1584
# Processed 1126/1584
# Processed 1127/1584
# Processed 1128/1584
# Processed 1129/1584
# Processed 1130/1584
# Processed 1131/1584
# Processed 1132/1584
# Processed 1133/1584
# Processed 1134/1584
# Processed 1135/1584
# Processed 1136/1584
# Processed 1137/1584
# Processed 1138/1584
# Processed 1139/1584
# Processed 1140/1584
# Processed 1141/1584
# Processed 1142/1584
# Processed 1143/1584
# Processed 1144/1584
# Processed 1145/1584
# Processed 1146/1584
# Processed 1147/1584
# Processed 1148/1584
# Processed 1149/1584
# Processed 1150/1584
# Processed 1151/1584
# Processed 1152/1584
# Processed 1153/1584
# Processed 1154/1584
# Processed 1155/1584
# Processed 1156/1584
# Processed 1157/1584
# Processed 1158/1584
# Processed 1159/1584
# Processed 1160/1584
# Processed 1161/1584
# Processed 1162/1584
# Processed 1163/1584
# Processed 1164/1584
# Processed 1165/1584
# Processed 1166/1584
# Processed 1167/1584
# Processed 1168/1584
# Processed 1169/1584
# Processed 1170/1584
# Processed 1171/1584
# Processed 1172/1584
# Processed 1173/1584
# Processed 1174/1584
# Processed 1175/1584
# Processed 1176/1584
# Processed 1177/1584
# Processed 1178/1584
# Processed 1179/1584
# Processed 1180/1584
# Processed 1181/1584
# Processed 1182/1584
# Processed 1183/1584
# Processed 1184/1584
# Processed 1185/1584
# Processed 1186/1584
# Processed 1187/1584
# Processed 1188/1584
# Processed 1189/1584
# Processed 1190/1584
# Processed 1191/1584
# Processed 1192/1584
# Processed 1193/1584
# Processed 1194/1584
# Processed 1195/1584
# Processed 1196/1584
# Processed 1197/1584
# Processed 1198/1584
# Processed 1199/1584
# Processed 1200/1584
# Processed 1201/1584
# Processed 1202/1584
# Processed 1203/1584
# Processed 1204/1584
# Processed 1205/1584
# Processed 1206/1584
# Processed 1207/1584
# Processed 1208/1584
# Processed 1209/1584
# Processed 1210/1584
# Processed 1211/1584
# Processed 1212/1584
# Processed 1213/1584
# Processed 1214/1584
# Processed 1215/1584
# Processed 1216/1584
# Processed 1217/1584
# Processed 1218/1584
# Processed 1219/1584
# Processed 1220/1584
# Processed 1221/1584
# Processed 1222/1584
# Processed 1223/1584
# Processed 1224/1584
# Processed 1225/1584
# Processed 1226/1584
# Processed 1227/1584
# Processed 1228/1584
# Processed 1229/1584
# Processed 1230/1584
# Processed 1231/1584
# Processed 1232/1584
# Processed 1233/1584
# Processed 1234/1584
# Processed 1235/1584
# Processed 1236/1584
# Processed 1237/1584
# Processed 1238/1584
# Processed 1239/1584
# Processed 1240/1584
# Processed 1241/1584
# Processed 1242/1584
# Processed 1243/1584
# Processed 1244/1584
# Processed 1245/1584
# Processed 1246/1584
# Processed 1247/1584
# Processed 1248/1584
# Processed 1249/1584
# Processed 1250/1584
# Processed 1251/1584
# Processed 1252/1584
# Processed 1253/1584
# Processed 1254/1584
# Processed 1255/1584
# Processed 1256/1584
# Processed 1257/1584
# Processed 1258/1584
# Processed 1259/1584
# Processed 1260/1584
# Processed 1261/1584
# Processed 1262/1584
# Processed 1263/1584
# Processed 1264/1584
# Processed 1265/1584
# Processed 1266/1584
# Processed 1267/1584
# Processed 1268/1584
# Processed 1269/1584
# Processed 1270/1584
# Processed 1271/1584
# Processed 1272/1584
# Processed 1273/1584
# Processed 1274/1584
# Processed 1275/1584
# Processed 1276/1584
# Processed 1277/1584
# Processed 1278/1584
# Processed 1279/1584
# Processed 1280/1584
# Processed 1281/1584
# Processed 1282/1584
# Processed 1283/1584
# Processed 1284/1584
# Processed 1285/1584
# Processed 1286/1584
# Processed 1287/1584
# Processed 1288/1584
# Processed 1289/1584
# Processed 1290/1584
# Processed 1291/1584
# Processed 1292/1584
# Processed 1293/1584
# Processed 1294/1584
# Processed 1295/1584
# Processed 1296/1584
# Processed 1297/1584
# Processed 1298/1584
# Processed 1299/1584
# Processed 1300/1584
# Processed 1301/1584
# Processed 1302/1584
# Processed 1303/1584
# Processed 1304/1584
# Processed 1305/1584
# Processed 1306/1584
# Processed 1307/1584
# Processed 1308/1584
# Processed 1309/1584
# Processed 1310/1584
# Processed 1311/1584
# Processed 1312/1584
# Processed 1313/1584
# Processed 1314/1584
# Processed 1315/1584
# Processed 1316/1584
# Processed 1317/1584
# Processed 1318/1584
# Processed 1319/1584
# Processed 1320/1584
# Processed 1321/1584
# Processed 1322/1584
# Processed 1323/1584
# Processed 1324/1584
# Processed 1325/1584
# Processed 1326/1584
# Processed 1327/1584
# Processed 1328/1584
# Processed 1329/1584
# Processed 1330/1584
# Processed 1331/1584
# Processed 1332/1584
# Processed 1333/1584
# Processed 1334/1584
# Processed 1335/1584
# Processed 1336/1584
# Processed 1337/1584
# Processed 1338/1584
# Processed 1339/1584
# Processed 1340/1584
# Processed 1341/1584
# Processed 1342/1584
# Processed 1343/1584
# Processed 1344/1584
# Processed 1345/1584
# Processed 1346/1584
# Processed 1347/1584
# Processed 1348/1584
# Processed 1349/1584
# Processed 1350/1584
# Processed 1351/1584
# Processed 1352/1584
# Processed 1353/1584
# Processed 1354/1584
# Processed 1355/1584
# Processed 1356/1584
# Processed 1357/1584
# Processed 1358/1584
# Processed 1359/1584
# Processed 1360/1584
# Processed 1361/1584
# Processed 1362/1584
# Processed 1363/1584
# Processed 1364/1584
# Processed 1365/1584
# Processed 1366/1584
# Processed 1367/1584
# Processed 1368/1584
# Processed 1369/1584
# Processed 1370/1584
# Processed 1371/1584
# Processed 1372/1584
# Processed 1373/1584
# Processed 1374/1584
# Processed 1375/1584
# Processed 1376/1584
# Processed 1377/1584
# Processed 1378/1584
# Processed 1379/1584
# Processed 1380/1584
# Processed 1381/1584
# Processed 1382/1584
# Processed 1383/1584
# Processed 1384/1584
# Processed 1385/1584
# Processed 1386/1584
# Processed 1387/1584
# Processed 1388/1584
# Processed 1389/1584
# Processed 1390/1584
# Processed 1391/1584
# Processed 1392/1584
# Processed 1393/1584
# Processed 1394/1584
# Processed 1395/1584
# Processed 1396/1584
# Processed 1397/1584
# Processed 1398/1584
# Processed 1399/1584
# Processed 1400/1584
# Processed 1401/1584
# Processed 1402/1584
# Processed 1403/1584
# Processed 1404/1584
# Processed 1405/1584
# Processed 1406/1584
# Processed 1407/1584
# Processed 1408/1584
# Processed 1409/1584
# Processed 1410/1584
# Processed 1411/1584
# Processed 1412/1584
# Processed 1413/1584
# Processed 1414/1584
# Processed 1415/1584
# Processed 1416/1584
# Processed 1417/1584
# Processed 1418/1584
# Processed 1419/1584
# Processed 1420/1584
# Processed 1421/1584
# Processed 1422/1584
# Processed 1423/1584
# Processed 1424/1584
# Processed 1425/1584
# Processed 1426/1584
# Processed 1427/1584
# Processed 1428/1584
# Processed 1429/1584
# Processed 1430/1584
# Processed 1431/1584
# Processed 1432/1584
# Processed 1433/1584
# Processed 1434/1584
# Processed 1435/1584
# Processed 1436/1584
# Processed 1437/1584
# Processed 1438/1584
# Processed 1439/1584
# Processed 1440/1584
# Processed 1441/1584
# Processed 1442/1584
# Processed 1443/1584
# Processed 1444/1584
# Processed 1445/1584
# Processed 1446/1584
# Processed 1447/1584
# Processed 1448/1584
# Processed 1449/1584
# Processed 1450/1584
# Processed 1451/1584
# Processed 1452/1584
# Processed 1453/1584
# Processed 1454/1584
# Processed 1455/1584
# Processed 1456/1584
# Processed 1457/1584
# Processed 1458/1584
# Processed 1459/1584
# Processed 1460/1584
# Processed 1461/1584
# Processed 1462/1584
# Processed 1463/1584
# Processed 1464/1584
# Processed 1465/1584
# Processed 1466/1584
# Processed 1467/1584
# Processed 1468/1584
# Processed 1469/1584
# Processed 1470/1584
# Processed 1471/1584
# Processed 1472/1584
# Processed 1473/1584
# Processed 1474/1584
# Processed 1475/1584
# Processed 1476/1584
# Processed 1477/1584
# Processed 1478/1584
# Processed 1479/1584
# Processed 1480/1584
# Processed 1481/1584
# Processed 1482/1584
# Processed 1483/1584
# Processed 1484/1584
# Processed 1485/1584
# Processed 1486/1584
# Processed 1487/1584
# Processed 1488/1584
# Processed 1489/1584
# Processed 1490/1584
# Processed 1491/1584
# Processed 1492/1584
# Processed 1493/1584
# Processed 1494/1584
# Processed 1495/1584
# Processed 1496/1584
# Processed 1497/1584
# Processed 1498/1584
# Processed 1499/1584
# Processed 1500/1584
# Processed 1501/1584
# Processed 1502/1584
# Processed 1503/1584
# Processed 1504/1584
# Processed 1505/1584
# Processed 1506/1584
# Processed 1507/1584
# Processed 1508/1584
# Processed 1509/1584
# Processed 1510/1584
# Processed 1511/1584
# Processed 1512/1584
# Processed 1513/1584
# Processed 1514/1584
# Processed 1515/1584
# Processed 1516/1584
# Processed 1517/1584
# Processed 1518/1584
# Processed 1519/1584
# Processed 1520/1584
# Processed 1521/1584
# Processed 1522/1584
# Processed 1523/1584
# Processed 1524/1584
# Processed 1525/1584
# Processed 1526/1584
# Processed 1527/1584
# Processed 1528/1584
# Processed 1529/1584
# Processed 1530/1584
# Processed 1531/1584
# Processed 1532/1584
# Processed 1533/1584
# Processed 1534/1584
# Processed 1535/1584
# Processed 1536/1584
# Processed 1537/1584
# Processed 1538/1584
# Processed 1539/1584
# Processed 1540/1584
# Processed 1541/1584
# Processed 1542/1584
# Processed 1543/1584
# Processed 1544/1584
# Processed 1545/1584
# Processed 1546/1584
# Processed 1547/1584
# Processed 1548/1584
# Processed 1549/1584
# Processed 1550/1584
# Processed 1551/1584
# Processed 1552/1584
# Processed 1553/1584
# Processed 1554/1584
# Processed 1555/1584
# Processed 1556/1584
# Processed 1557/1584
# Processed 1558/1584
# Processed 1559/1584
# Processed 1560/1584
# Processed 1561/1584
# Processed 1562/1584
# Processed 1563/1584
# Processed 1564/1584
# Processed 1565/1584
# Processed 1566/1584
# Processed 1567/1584
# Processed 1568/1584
# Processed 1569/1584
# Processed 1570/1584
# Processed 1571/1584
# Processed 1572/1584
# Processed 1573/1584
# Processed 1574/1584
# Processed 1575/1584
# Processed 1576/1584
# Processed 1577/1584
# Processed 1578/1584
# Processed 1579/1584
# Processed 1580/1584
# Processed 1581/1584
# Processed 1582/1584
# Processed 1583/1584
# Processed 1584/1584
# Итоговый датасет с классификацией сохранен в data/qas/combined_dataset_with_classification.json
